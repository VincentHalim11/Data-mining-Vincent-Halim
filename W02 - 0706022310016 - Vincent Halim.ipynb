# %%
#vincent Halim - 0706022310016
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
url = "https://raw.githubusercontent.com/NathaliaMinoque/datasets/refs/heads/main/jabodetabek_house_price.csv"
df = pd.read_csv(url,sep=',')
df.head()
# Out:
#                                                  url   price_in_rp  \
# 0  https://www.rumah123.com/properti/bekasi/hos11...  2.990000e+09
# 1  https://www.rumah123.com/properti/bekasi/hos10...  1.270000e+09
# 2  https://www.rumah123.com/properti/bekasi/hos10...  1.950000e+09
# 3  https://www.rumah123.com/properti/bekasi/hos10...  3.300000e+09
# 4  https://www.rumah123.com/properti/bekasi/hos10...  4.500000e+09
#
#                                                title  \
# 0  Rumah cantik Sumarecon Bekasi\nLingkungan asri...
# 1          Rumah Kekinian, Magenta Summarecon Bekasi
# 2  Rumah Cantik 2 Lantai Cluster Bluebell Summare...
# 3  Rumah Mewah 2Lantai L10x18 C di Cluster VERNON...
# 4  Rumah Hoek di Cluster Maple Summarecon Bekasi,...
#
#                      address           district     city       lat  \
# 0  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# 1  Summarecon Bekasi, Bekasi  Summarecon Bekasi   Bekasi -6.223945
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3553 entries, 0 to 3552
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   url                   3553 non-null   object
#  1   price_in_rp           3553 non-null   float64
#  2   title                 3553 non-null   object
#  3   address               3553 non-null   object
#  4   district              3553 non-null   object
#  5   city                  3553 non-null   object
#  6   lat                   3553 non-null   float64
#  7   long                  3553 non-null   float64
#  8   facilities            3553 non-null   object
#  9   property_type         3552 non-null   object
#  10  ads_id                3549 non-null   object
#  11  bedrooms              3519 non-null   float64
#  12  bathrooms             3524 non-null   float64
#  13  land_size_m2          3551 non-null   float64
# ...

# %%
df.describe()
# Out:
#         price_in_rp          lat         long     bedrooms    bathrooms  \
# count  3.553000e+03  3553.000000  3553.000000  3519.000000  3524.000000
# mean   4.191685e+09    -6.324721   106.792881     3.326513     2.624858
# std    1.375067e+10     0.129245     0.172159     2.672148     2.696497
# min    4.200000e+07    -6.894828   106.402315     1.000000     1.000000
# 25%    8.000000e+08    -6.397933   106.687295     2.000000     2.000000
# 50%    1.500000e+09    -6.300733   106.799954     3.000000     2.000000
# 75%    3.590000e+09    -6.231754   106.874766     4.000000     3.000000
# max    5.800000e+11    -6.102478   109.771691    99.000000    99.000000
#
#        land_size_m2  building_size_m2     carports  maid_bedrooms  \
# count   3551.000000       3551.000000  3553.000000    3553.000000
# mean     204.806815        186.587440     1.197861       0.496482
# std      402.127746        248.443471     1.114996       0.685723
# ...

# %%
null_sum = df.isnull().sum()
null_perc = (null_sum/len(df))*100

null_df = pd.DataFrame({'Null Count' : null_sum, 'Null Percentages' : null_perc})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]

# Format the percentage with two decimal places and % symbol
null_df['Null Percentages'] = null_df['Null Percentages'].map('{:.2f}%'.format)
null_df
# Out:
#                       Null Count Null Percentages
# property_type                  1            0.03%
# ads_id                         4            0.11%
# bedrooms                      34            0.96%
# bathrooms                     29            0.82%
# land_size_m2                   2            0.06%
# building_size_m2               2            0.06%
# certificate                  141            3.97%
# floors                         6            0.17%
# building_age                1445           40.67%
# year_built                  1445           40.67%
# property_condition           246            6.92%
# building_orientation        1647           46.36%
# furnishing                   387           10.89%

# %%
#dari dataset ini dapat disimpulkan jika ada 3552 data tetapi juga ditemukan banyak data yang kosong
#terutama di bagian building_orientation hingga 1647 data selain itu masih ada building_age dan year_built yang sama 1445 data
#tetapi ada juga yang hanya kosong sedikit contohnya di porperty type yang hanya memiliki 1 data kosong

# %% [markdown]
# MISSING DATA

# %%
# data kosong bagian ini aku memilih untuk mengisi data kosong dengan mediannya. karena aku merasa cukup banyak jika harus didrop
col = ["bedrooms","bathrooms","land_size_m2","building_size_m2","floors"]
for cols in col:
    df[cols].fillna(df[cols].median(), inplace= True)
# Out:
# /tmp/ipython-input-544104838.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[cols].fillna(df[cols].median(), inplace= True)

# %%
#aku merasa ini juga memilih untuk mengisi data ini akan tetapi aku memilih untuk mengisinya dengan "unknown" karena isi data bukan
# int  aku melakukan ini untuk mencegah kehilangan banyak data
kol = ["certificate","building_age","year_built","property_condition","building_orientation","furnishing"]
df[kol] = df[kol].fillna("Unknown")

# %%
#aku memilih untuk menghapus data ini karena data ini kecil hanya 1 hingga 4 data saja dan karena data awal ada 3552 data aku rasa
#kehilangan 1-4 data tidak memberikan pengruh yang besar
df = df.dropna(subset=["ads_id","property_type"])

# %%
null_sum = df.isnull().sum()
null_perc = (null_sum/len(df))*100

null_df = pd.DataFrame({'Null Count' : null_sum, 'Null Percentages' : null_perc})

# Filter for columns with null values
null_df = null_df[null_df['Null Count'] > 0]

# Format the percentage with two decimal places and % symbol
null_df['Null Percentages'] = null_df['Null Percentages'].map('{:.2f}%'.format)
null_df
# Out:
# Empty DataFrame
# Columns: [Null Count, Null Percentages]
# Index: []

# %%
# binning
bins = [0, 2, 4, 6, 8, 10, df["bedrooms"].max()]
labels = ["0-2", "3-4", "5-6", "7-8", "9-10", "10+"]
df["bedrooms_bin"] = pd.cut(df["bedrooms"], bins=bins, labels=labels, include_lowest=True)


plt.figure(figsize=(7,5))
sn.countplot(x="bedrooms_bin", data=df, palette="Blues")
plt.title("Binning Barchart Bedrooms")
plt.xlabel("Jumlah Bedrooms (bin)")
plt.ylabel("Jumlah Properti")
plt.show()
# Out:
# /tmp/ipython-input-3087036665.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sn.countplot(x="bedrooms_bin", data=df, palette="Blues")

# %%
for col in df.columns:
  print(f"Unique values for column '{col}':")
  print(df[col].unique())
  print("-" * 20)
# Out:
# Unique values for column 'url':
# ['https://www.rumah123.com/properti/bekasi/hos11360272/#qid~213b5619-a399-47b3-bfcf-faaef6b542d5'
#  'https://www.rumah123.com/properti/bekasi/hos10680347/#qid~748f5d2d-8d3a-4a4e-a1b4-37c7be7ffc25'
#  'https://www.rumah123.com/properti/bekasi/hos10685867/#qid~f6c2cf9d-44fa-4c1a-8749-8ee96b116e93'
#  ...
#  'https://www.rumah123.com/properti/tangerang/hos11359594/#qid~0d9492e8-7326-465d-85ee-e54559fedc26'
#  'https://www.rumah123.com/properti/tangerang/hos11359313/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0'
#  'https://www.rumah123.com/properti/tangerang/hos11358964/#qid~5d5b05f9-ab0d-4774-ae61-bddd6e38b7f0']
# --------------------
# Unique values for column 'price_in_rp':
# [2.99e+09 1.27e+09 1.95e+09 3.30e+09 4.50e+09 2.70e+09 2.35e+09 2.90e+09
#  2.55e+09 9.52e+08 1.80e+09 2.50e+09 5.36e+09 2.25e+09 2.45e+09 1.25e+08
#  1.98e+09 7.64e+08 2.00e+09 4.80e+08 1.90e+09 3.00e+08 5.27e+09 2.80e+09
# ...

# %%
city_counts = df["city"].value_counts()
print(city_counts)

plt.figure(figsize=(10,5))
sn.countplot(data=df, x="city", order=df["city"].value_counts().index)

plt.title("Jumlah Properti per Kota")
plt.xticks(rotation=45)
plt.show()
#disini saya menggunakan barchart  untuk mencari tau banyak rumah yang tersebar di kota-kota dimana ditemukan 881 rumah terletak di bogor
#dan kota dengan rumah terbanyak ada di tanggerang dengan sebesar 848 dan disusul dengan kota bekasi dengan jumlah yang cukup menurun jika
#dibandingkan dengan kota - kota sebelumnya yaitu di 586 rumah
# Out:
# city
# Bogor              881
# Tangerang          848
# Bekasi             586
# Depok              526
# Jakarta Selatan    240
# Jakarta Barat      206
# Jakarta Utara      129
# Jakarta Timur       95
# Jakarta Pusat       38
# Name: count, dtype: int64

# %%
condition_counts = df["property_condition"].value_counts()
print(condition_counts)


df["property_condition"].value_counts().plot(
    kind="barh",
    figsize=(8,6),
    color="skyblue"
)

plt.title("Distribusi Kondisi Properti")
plt.xlabel("Jumlah")
plt.ylabel("Kondisi")
plt.show()
#disini saya menganalisis kondisi properti dimana ditemukan kondisi paling banyak adalah rumah dengan kondisi bagus dengan sebanyak 1437 rumah
# disusul dengan rumah dengan kondisi baru sebanyak 1328 rumah. sedangkan yang paling sedikit adalah rumah dengan kondisi semi furnished
# hanya dengan 4 rumah saja.
# Out:
# property_condition
# bagus             1437
# baru              1328
# bagus sekali       261
# Unknown            242
# sudah renovasi     158
# butuh renovasi      94
# unfurnished         25
# semi furnished       4
# Name: count, dtype: int64

# %%
furnishing_counts = df["furnishing"].value_counts()
print(furnishing_counts)

df["furnishing"].value_counts().plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6),
    startangle=90
)

plt.ylabel("")
plt.title("Distribusi Kondisi Properti")
plt.show()

# disini adakah distribusi kondisi properti dengan menggunakan pie chart. dimana didapatkan banyak rumah dengan kondisi unfurnished dengan
# persentase sebanyak 58.2% disusul dengan rumah dengan kondisi semi - furnished dengan 23.5% dan yang pling sedikit adalah rumah dalam
# kondisi baru dimana hanya 0.8% saja
# Out:
# furnishing
# unfurnished       2066
# semi furnished     833
# Unknown            383
# furnished          238
# baru                29
# Name: count, dtype: int64

# %%
cols = ["maid_bedrooms", "maid_bathrooms"]

for col in cols:
    plt.figure(figsize=(5,4))
    plt.boxplot(df[col].dropna())
    plt.title(f"Boxplot {col}")
    plt.ylabel(col)
    plt.show()

# dari boxplot ini didapatkan jika rumah - rumah kebanyakan tidak memiliki kamar mandi dan kamar pembantu tetapi muncul outlier yang
# signifikan menunjukan rumah - rumah yang memiliki kamar dan kamar mandi pembantu adalah rumah mewah

# %%
plt.figure(figsize=(7,5))
plt.scatter(df["building_size_m2"], df["price_in_rp"], alpha=0.5)
plt.xlabel("Land Size (m2)")
plt.ylabel("Price (Rp)")
plt.title("Scatter Plot: Land Size vs Price")
plt.show()


plt.figure(figsize=(7,5))
plt.scatter(df["bedrooms"], df["price_in_rp"], alpha=0.5)
plt.xlabel("bedrooms")
plt.ylabel("Price (Rp)")
plt.title("Scatter Plot: bedroom vs Price")
plt.show()
# ini adalah scatter plot yang menunjukkan korelasi antara land size dan harga
# dan bedroom dengan harga dimana didapatkan rumah yang punya luas tanah
# < 1000 m²  dengan harga di bawah 1e11 (100 miliar Rp).
# tapi disini juga menunjukan ada rumah yang hanya memiliki 500m² tetapi memiliki
#harga yang sangat tinggi sedangkan ada rumah dengan luas 6000m² dijual dengan
#harga yang lebih murah bisa jadi ini karena fasilitas dan lokasi

#sedangkan untuk bagian harga dan bedroom ditemukan mayoritas rumah memiliki
#kamar < 10 kamar akan tetapi ada data yang menunjukkan 1 rumah yang memiliki
#100 kamar dimana kemungkinan ini adalah apartemen atau kos
